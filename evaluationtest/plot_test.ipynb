# %%
# libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Dataset
df=pd.DataFrame({'X': range(1,101), 'Y': np.random.randn(100)*15+range(1,101), 'Z': (np.random.randn(100)*15+range(1,101))*2 })

# plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['X'], df['Y'], df['Z'], c='skyblue', s=60)
ax.view_init(30, 185)
plt.show()

# %%
TruePositive=np.random.uniform(90,101,[40]) 
FalseNegative=100-TruePositive
FalsePositive=np.random.uniform(0,20,[40]) 

TruePositive2=np.random.uniform(80,95,[40]) 
FalseNegative2=100-TruePositive
FalsePositive2=np.random.uniform(0,25,[40]) 

TruePositive3=np.random.uniform(60,90,[40]) 
FalseNegative3=100-TruePositive
FalsePositive3=np.random.uniform(0,30,[40]) 
dataset = TruePositive,FalseNegative,FalsePositive
print(dataset)
# Out:
# (array([ 97.44150343, 100.09116366, 100.65932357,  94.60957478,
#         93.98948566,  95.87770978,  95.01305481,  97.39374937,
#        100.37265089, 100.15448839,  98.91090335,  96.61009775,
#         90.06330615,  99.78347891,  91.79834184, 100.18307963,
#         98.98056387,  99.46012159,  95.37988327,  93.64078008,
#         94.90162044,  92.16418161,  94.1129721 ,  93.14486935,
#         99.60606478,  97.71110041,  95.36851634,  91.5097177 ,
#         90.78150533,  99.14297072,  95.48453977, 100.61933256,
#         98.07501995,  95.24261636,  97.23190587,  91.06892087,
#         92.11256075,  98.03059446,  94.41567942,  95.78559961]), array([ 2.55849657, -0.09116366, -0.65932357,  5.39042522,  6.01051434,
#         4.12229022,  4.98694519,  2.60625063, -0.37265089, -0.15448839,
#         1.08909665,  3.38990225,  9.93669385,  0.21652109,  8.20165816,
#        -0.18307963,  1.01943613,  0.53987841,  4.62011673,  6.35921992,
#         5.09837956,  7.83581839,  5.8870279 ,  6.85513065,  0.39393522,
#         2.28889959,  4.63148366,  8.4902823 ,  9.21849467,  0.85702928,
#         4.51546023, -0.61933256,  1.92498005,  4.75738364,  2.76809413,
#         8.93107913,  7.88743925,  1.96940554,  5.58432058,  4.21440039]), array([10.67338701,  5.80487452,  9.00616466,  2.97902826,  5.98067318,
#        15.12153873, 17.78565453, 17.69452814, 18.6046484 , 15.46061768,
#         6.89280553,  0.60933371,  7.65619303,  6.60986289,  6.3389717 ,
#         8.21314497,  1.79849825,  3.97160014,  1.91435248,  5.95573163,
#         2.35401778,  2.53180662,  6.71354097,  2.42206732,  1.05804795,
#         7.97282404,  3.16233715,  3.35233173,  3.33027949, 18.80849829,
#        15.11000064, 15.89852677, 13.27253272, 10.19209404, 10.71776209,
#        13.89346799,  7.95653345,  8.94173791, 10.16393201, 12.89697549]))

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')


ax.scatter(FalseNegative, FalsePositive, TruePositive, label='data set 1')
ax.scatter(FalseNegative2, FalsePositive2, TruePositive2, c="red", label='data set 2')
ax.scatter(FalseNegative3, FalsePositive3, TruePositive3, c="green", label='data set 2')

ax.legend()
ax.set_xlim(50, 0)
ax.set_ylim(0, 30)
ax.set_zlim(50, 100)
ax.set_xlabel('FalseNegative')
ax.set_ylabel('FalsePositive')
ax.set_zlabel('TruePositive')
ax.view_init(elev=15., azim=20)
plt.show()
