# %%
# %autoreload 2

from matplotlib import pyplot as plt
plt.show()z
# Out:
#   File "<ipython-input-4-24b30fa0494f>", line 4
#     plt.show()z
#               ^
# SyntaxError: invalid syntax

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter
from M3 import m3Denoising
from M3 import m3Batch as m3Batch
from M3 import m3Show

# sys.path.append('../M3')

# **********************************************************************
# exampe of input
'''
fArray = {function1: {"inputImg": "ignorethis", "param1": "blalbal1"},
          function2: {"inputImg": "ignorethis", "param2": "blalbal2"}}
'''
# **********************************************************************
# fArray = {m3Face.findEyes: {"image": "ignorethis"},
#           m3HoughCircle.findCircle: {"image": "ignorethis"}}

fArray = {m3Show.Histogram: {"inputImg": "ignorethis"}, m3Show.rgbToHSV: {"inputImg": "ignorethis"}, m3Show.scatter: {"inputImg": "ignorethis"}, m3Show.imshow:{"inputImg": "ignorethis","title":"output"},
        m3Show.h_Pass: {"inputImg": "ignorethis"}, m3Show.r_channel: {"inputImg": "ignorethis"}}


#print(m3F.printRed("TRALALA"))
m3Batch.batchProcess("PICTURES/Eyes/Eyes_set1/", fArray, False)
# Out:
# ************************************************************            ****************************************************
# processing: PICTURES/Eyes/Eyes_set1/photo3_Face_1_Right.jpeg
# **************************************
# running<function Histogram at 0x1245ff158>
# **************************************
# running<function rgbToHSV at 0x1245ff1e0>
# **************************************
# running<function scatter at 0x12458f268>
# **************************************
# running<function imshow at 0x12458f1e0>
# **************************************
# running<function h_Pass at 0x1245ff268>
# **************************************
# running<function r_channel at 0x1245ff378>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-37bf16adbabf> in <module>
#      26
#      27 #print(m3F.printRed("TRALALA"))
# ---> 28 m3Batch.batchProcess("PICTURES/Eyes/Eyes_set1/", fArray, False)
#
# ~/Desktop/University/3. semester/P3 Project/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Batch.py in batchProcess(inputFolder, functionArray, export)
#     134             print("**************************************")
#     135             print("running" + str(function))
# --> 136             outputImage = function(**currentFunction)
#     137             inputImage = outputImage
#     138         # else:
#
# ~/Desktop/University/3. semester/P3 Project/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Show.py in r_channel(inputImg)
#     149 def r_channel (inputImg):
#     150
# --> 151     img = imread(inputImg,1)
#     152     b,g,r = cv2.split(img)
#     153     cv2.imshow('Blue Channel',b)
#
# NameError: name 'imread' is not defined

# %% [markdown]
# #
