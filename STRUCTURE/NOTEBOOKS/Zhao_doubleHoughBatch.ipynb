# %%
from STRUCTURE.NOTEBOOKS.M3 import m3Show, m3MedianFilter, m3Denoising
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt


plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Show as m3Show
from STRUCTURE.NOTEBOOKS.Retinex import retinexRunnable

# sys.path.append('../M3')

# **********************************************************************
# exampe of input
'''
fArray = {function1: {"inputImg": "ignorethis", "param1": "blalbal1"},
          function2: {"inputImg": "ignorethis", "param2": "blalbal2"}}
'''
# **********************************************************************
# fArray = {m3Face.findEyes: {"image": "ignorethis"},
#           m3HoughCircle.findCircle: {"image": "ignorethis"}}
fArray = {
    # m3Show.imshow: {"inputImg": "ignorethis", "title": "input img"},
    retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": False},
    m3MedianFilter.medianFilter: {"inputImg": "ignorethis", "show": False},
    m3F.getRed: {"inputImg": "ignorethis", "show": False},
    #m3Denoising.denoise: {"inputImg": "ignorethis", "show": True}
    m3HoughCircle.findCircleSimpleDouble: {"inputImg": "ignorethis", "show": True}


    }


m3Batch.batchProcess("PICTURES/Eyes/", fArray, False)
# Out:
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo10_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 11
# CIRCLES FOUND^^^\]
# img out (68, 133)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo10_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (64, 128)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo11_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 11
# CIRCLES FOUND^^^\]
# img out (69, 124)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo11_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (65, 124)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo12_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 15
# CIRCLES FOUND^^^\]
# img out (95, 190)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo12_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 15
# CIRCLES FOUND^^^\]
# img out (94, 194)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo13_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 11
# CIRCLES FOUND^^^\]
# img out (66, 124)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo13_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 11
# CIRCLES FOUND^^^\]
# img out (67, 116)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo14_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 12
# CIRCLES FOUND^^^\]
# img out (74, 148)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo14_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 12
# CIRCLES FOUND^^^\]
# img out (73, 144)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo15_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 7
# CIRCLES FOUND^^^\]
# img out (46, 89)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo15_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 7
# CIRCLES FOUND^^^\]
# img out (45, 90)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo16_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (26, 50)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo16_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 5
# CIRCLES FOUND^^^\]
# img out (30, 62)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo17_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (64, 124)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo17_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (63, 128)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo18_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 15
# CIRCLES FOUND^^^\]
# img out (94, 168)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo18_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 15
# CIRCLES FOUND^^^\]
# img out (94, 177)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo19_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 17
# CIRCLES FOUND^^^\]
# img out (104, 180)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo19_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 16
# CIRCLES FOUND^^^\]
# img out (99, 185)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo2_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (25, 49)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo2_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (25, 50)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo3_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (25, 51)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo3_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (25, 49)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo4_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 7
# CIRCLES FOUND^^^\]
# img out (44, 92)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo4_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 8
# CIRCLES FOUND^^^\]
# img out (48, 89)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo6_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 5
# CIRCLES FOUND^^^\]
# img out (32, 61)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo6_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 5
# CIRCLES FOUND^^^\]
# img out (31, 52)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo8_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (26, 44)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo8_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 4
# CIRCLES FOUND^^^\]
# img out (28, 52)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo9_Face_1_Left.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 11
# CIRCLES FOUND^^^\]
# img out (67, 104)
# ************************************************************                ****************************************************
# processing: PICTURES/Eyes\photo9_Face_1_Right.jpeg
# **************************************
# running<function runMSRCP at 0x0000024218999048>
# **************************************
# running<function medianFilter at 0x0000024215828AF8>
# **************************************
# running<function getRed at 0x0000024215755AF8>
# **************************************
# running<function findCircleSimpleDouble at 0x000002421A42F4C8>
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (64, 104)
