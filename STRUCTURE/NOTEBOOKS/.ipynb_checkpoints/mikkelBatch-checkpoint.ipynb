# %%
from matplotlib import pyplot as plt
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch

# sys.path.append('../M3')

# **********************************************************************
# exampe of input
'''
fArray = {function1: {"image": "ignorethis", "param1": "blalbal1"},
          function2: {"image": "ignorethis", "param2": "blalbal2"}}
'''
# **********************************************************************
# fArray = {m3Face.findEyes: {"image": "ignorethis"},
#           m3HoughCircle.findCircle: {"image": "ignorethis"}}
fArray = {m3HoughCircle.findCircle: {"inputImg": "ignorethis"}}

#print(m3F.printRed("TRALALA"))
m3Batch.batchProcess("PICTURES/Eyes/", fArray, False)
# Out:
# ***************************************************************************************
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-e3d9fafb960d> in <module>
#      20
#      21 #print(m3F.printRed("TRALALA"))
# ---> 22 m3Batch.batchProcess("PICTURES/Eyes/", fArray, False)
#      23
#      24
#
# ~\PycharmProjects\P3-G306\STRUCTURE\NOTEBOOKS\M3\m3Batch.py in batchProcess(inputFolder, functionArray, export)
#      53                 # m3F.imshow(inputImage, "BATCH DEBUGGING")
#      54                 # https://realpython.com/python-kwargs-and-args/
# ---> 55                 outputImage = key(**current)
#      56                 inputImage = outputImage
#      57         else:
#
# ~\PycharmProjects\P3-G306\STRUCTURE\NOTEBOOKS\M3\m3HoughCircle.py in findCircle(inputImg)
#      15
#      16 def findCircle(inputImg):
# ---> 17     run(inputImg, 1, 120, 60, 15, 10, 100)
#      18
#      19
#
# ~\PycharmProjects\P3-G306\STRUCTURE\NOTEBOOKS\M3\m3HoughCircle.py in run(tempInputImg, tempResolution, tempMin_dist, tempParam_1, tempParam_2, tempMinRadius, tempMaxRadius)
#      40                 for i in circles[0, :]:
#      41                     # draw the outer circle
# ---> 42                     cv2.circle(cimg, (i[0], i[1]), i[2], (0, 255, 0), 2)
#      43                     # draw the center of the circle
#      44                     cv2.circle(cimg, (i[0], i[1]), 2, (0, 0, 255), 3)
#
# IndexError: invalid index to scalar variable.
