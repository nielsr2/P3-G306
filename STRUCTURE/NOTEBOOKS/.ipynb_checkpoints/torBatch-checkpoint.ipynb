# %%
# %autoreload 2

from matplotlib import pyplot as plt
plt.show()z
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter
from M3 import m3Denoising
from M3 import m3Batch as m3Batch

# sys.path.append('../M3')

# **********************************************************************
# exampe of input
'''
fArray = {function1: {"inputImg": "ignorethis", "param1": "blalbal1"},
          function2: {"inputImg": "ignorethis", "param2": "blalbal2"}}
'''
# **********************************************************************
# fArray = {m3Face.findEyes: {"image": "ignorethis"},
#           m3HoughCircle.findCircle: {"image": "ignorethis"}}

fArray = {m3MedianFilter.medianFilter: {"inputImg": "ignorethis"},m3Denoising.denoise: {"inputImg": "ignorethis2"},m3HoughCircle.findCircle: {"inputImg": "ignorethis"}}


#print(m3F.printRed("TRALALA"))
m3Batch.batchProcess("PICTURES/Eyes/", fArray, False)
# Out:
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (99, 185)
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (26, 50)
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (95, 190)
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (94, 177)
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (104, 180)
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (64, 124)
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (66, 124)
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (94, 168)
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (74, 148)
# ***************************************************************************************
# 10
# CIRCLES FOUND^^^\]
# img out (64, 104)
# ***************************************************************************************
# 10
# NO CIRCLES FOUND^^^\]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ebb8b47fb8a6> in <module>
#      24
#      25 #print(m3F.printRed("TRALALA"))
# ---> 26 m3Batch.batchProcess("PICTURES/Eyes/", fArray, False)
#
# ~/Documents/GitHub/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Batch.py in batchProcess(inputFolder, functionArray, export)
#      53                 # m3F.imshow(inputImage, "BATCH DEBUGGING")
#      54                 # https://realpython.com/python-kwargs-and-args/
# ---> 55                 outputImage = key(**current)
#      56                 inputImage = outputImage
#      57         else:
#
# ~/Documents/GitHub/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Denoising.py in denoise(inputImg)
#      10
#      11 def denoise(inputImg):
# ---> 12     outputImg = cv2.fastNlMeansDenoisingColored(inputImg,7,21,20,10)
#      13     return outputImg
#
# KeyboardInterrupt:

# %% [markdown]
# #
