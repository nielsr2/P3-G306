# %%
from matplotlib import pyplot as plt
plt.show()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast
from M3 import m3Niels as m3Niels
from M3 import m3Class, m3Color, m3Size, m3Show, m3Edge, m3Comparison
#from M3 import m3ReduceAmountsOfColor



# pre-stuff

preFunctions = {
    
         m3Face.findEyes: {"show": True, "division": 8},
         m3Face.findEyes2: {"show": True, "division": 8}

    

}


fArray = {
        "doFor": {"original":"image", "doAs": "wip"},
        m3MedianFilter.medianFilter: {"kernelSize": 5, "show": True},
        retinexRunnable.runMSRCP: { "show": True},
        m3Color.reduceColor: {"n_colors": 5, "show": True},
        m3F.getRed: {"show": True},
        #m3Contrast.contrast: {"inputImg": "ignore", "show": False},
        m3tv.denoise_tv_chambolle: {"weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
#       m3Size.makeSmaller: {"eye": "asdfasf", "show": True, "scale": 6},
    
       # m3Show.Histogram: {"inputImg": "asfasdf"},
    

#        m3Mask.makePolyMask: {"photo": "asdfasdf"},

    
        # 194 
    # #   m3Mask.makeManyPolyMask: {"photo": "asdfasdf"}, 
    #        m3Mask.applyPolyMask: {"eye": "asdfasdf"}, 
    
        "doForEye": {},
        m3HoughCircle.findCircleAndMakeMask: { "eyeAttr":"wip", 
                                              "houghParams": 
                                              {"resolution": 1, "min_dist": 100, "param_1": 200, "param_2": 10, 
                                               "min_radius_width_divider": 7, "max_radius_width_divider": 5.5,
                                               "show": True},
                                              "maskParams" :
                                              {
                                                  
                                              }
                                             },
      #  m3Mask.makeCircularMask: {"photo": "asdfasdf"},
#        m3Mask.makeCircularOutline: {"photo": "asdfasd", "dest": "houghOutline"},
   #     m3Mask.applyCircMask: {"photo": "asdfasdf"}, 
            #m3i.i: {"eye": "afsadf"}
    
         }



# IRIS

#          _ . - = - . _
#        . "  \  \   /  /  " .
#      ,  \                 /  .
#    . \   _,.--~=~"~=~--.._   / .
#   ;  _.-"  / \ !   ! / \  "-._  .
#  / ,"     / ,` .---. `, \     ". \
# /.'   `~  |   /:::::\   |  ~`   '.\
# \`.  `~   |   \:::::/   | ~`  ~ .'/
#  \ `.  `~ \ `, `~~~' ,` /   ~`.' /
#   .  "-._  \ / !   ! \ /  _.-"  .
#    ./    "=~~.._  _..~~=`"    \.
#      ,/         ""          \,
#        . _/             \_ . 
#           " - ./. .\. - "

irisArray = {
        # m3Show.Histogram: {"inputImg": "asfasdf"},
      

        m3Mask.mask: {"eye": "asdfasdf", "img":"iris", "mask":"manyPolyMask", "dest": "irisJustPolyMasked"},  
      #  retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
      #   m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
       #  m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 3, "show": True},
       #  m3F.getRed: {"inputImg": "ignorethis", "show": True},
    #   m3Edge.canny: {"inputImg": "asdfasdf", "thresh1": 100, "thresh2": 200},
    #    m3Niels.storeAttr: {"photo": "asdf", "eyeAttr": ""}
    
    
   #     m3Mask.placeEyesInFull("photo": "blabla", "fullImgAttr": "originalImage", "eyeAttr":  )
         }



postFunctions = {m3Batch.loadMasksForComparison: {"maskFolder": "PICTURES/single_masked/"},
                m3Comparison.pixelcomparison: {},
                m3Batch.generateComparison: {"outputName":
                                             "newdataset-fixedhohg", 
                                             "attrs": 
                                                    ["image", "houghOutline", "irisJustPolyMasked", "manyPolyMask", "iris" ],
                                                     "folderName": "nielstesting-nibeasy-5", "exportFullMask": False, "CSV": True,
                                                     "settings": [preFunctions, fArray, irisArray]
                            }, 
}




pa = m3Batch.photoBatch("PICTURES/single/", fArray, debug=True, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
# Test_set_easy single Test_set_hard
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# **********************************************************************
# **********************************************************************
# DOING PRE FUNCIONS\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  findEyes <built-in method __dir__ of function object at 0x1c24833c80>
# function.__name__  in pre:  findEyes2 <built-in method __dir__ of function object at 0x1c255d88c8>
# **********************************************************************
# **********************************************************************
# DOING FUNCION ARRAY\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  medianFilter
# function.__name__  in pre:  runMSRCP
# function.__name__  in pre:  reduceColor
# function.__name__  in pre:  getRed
# function.__name__  in pre:  denoise_tv_chambolle
# /Users/n/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# function.__name__  in pre:  findCircleAndMakeMask
# ***************************************************************************************
# 61
# CIRCLES FOUND^^^\]
# img out (224, 432)
# circles [[[202 110  74]
#   [ 88 128  62]
#   [302 168  70]]]
# ***************************************************************************************
# 57
# CIRCLES FOUND^^^\]
# img out (208, 400)
# circles [[[192 102  69]]]
# **********************************************************************
# **********************************************************************
# DOING IRIS FUNCION ARRAY\]
# **********************************************************************
# function name mask\]
#  IMG OR MASK WAS NONE. NOT MASKING\]
#  IMG OR MASK WAS NONE. NOT MASKING\]
# LOADING:  PICTURES/single_masked/002Easy_mask.jpg FOR  PICTURES/single/002Easy.jpg

# %%
m3Niels.generateComparison(pa, fileName="iris")

# %%
#print(pa[0].faces[0].eyes[0].__dict__.items())
from M3 import m3Show 
print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aab4164778f0> in <module>
#       1 #print(pa[0].faces[0].eyes[0].__dict__.items())
#       2 from M3 import m3Show
# ----> 3 print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
#
# NameError: name 'pa' is not defined

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast, semi_circles, m3Color
from M3 import m3Niels as m3Niels
from M3 import m3Class

# %% [markdown]
# # LOOP OVER BATCHING

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast
from M3 import m3Niels as m3Niels
from M3 import m3Class, m3Color, m3Size, m3Show, m3Edge, m3Comparison
#from M3 import m3ReduceAmountsOfColor



# pre-stuff

preFunctions = {
    
         m3Face.findEyes: {"show": True, "division": 8},
         m3Face.findEyes2: {"show": True, "division": 8}

    
    #    m3Niels.fakeEyes: {} # pc boys u use dis, ( but then u can't use generateComparison)
}







fArray = {
        m3MedianFilter.medianFilter: {"inputImg": "ignore", "kernelSize": 5, "show": True},
        retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
        m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 4, "show": True},
        m3F.getRed: {"inputImg": "ignorethis", "show": True},
        #m3Contrast.contrast: {"inputImg": "ignore", "show": False},
        m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
#       m3Size.makeSmaller: {"eye": "asdfasf", "show": True, "scale": 6},
    
       # m3Show.Histogram: {"inputImg": "asfasdf"},
    
    
        m3Mask.makePolyMask: {"photo": "asdfasdf"},

    
        # 194 
        m3Mask.makeManyPolyMask: {"photo": "asdfasdf"}, 
            m3Mask.applyPolyMask: {"eye": "asdfasdf"}, 
    
    
        m3HoughCircle.findCircle: {"eye": "ignorethis", "resolution": 1, "min_dist": 100, "param_1": 200, "param_2": 10, 
                                    "min_radius_width_divider": 7, "max_radius_width_divider": 5.5, "show": True},
        m3Mask.makeCircularMask: {"photo": "asdfasdf"},
        m3Mask.makeCircularOutline: {"photo": "asdfasd", "dest": "houghOutline"},
        m3Mask.applyCircMask: {"photo": "asdfasdf"}, 
            #m3i.i: {"eye": "afsadf"}
    
         }



# IRIS

#          _ . - = - . _
#        . "  \  \   /  /  " .
#      ,  \                 /  .
#    . \   _,.--~=~"~=~--.._   / .
#   ;  _.-"  / \ !   ! / \  "-._  .
#  / ,"     / ,` .---. `, \     ". \
# /.'   `~  |   /:::::\   |  ~`   '.\
# \`.  `~   |   \:::::/   | ~`  ~ .'/
#  \ `.  `~ \ `, `~~~' ,` /   ~`.' /
#   .  "-._  \ / !   ! \ /  _.-"  .
#    ./    "=~~.._  _..~~=`"    \.
#      ,/         ""          \,
#        . _/             \_ . 
#           " - ./. .\. - "

irisArray = {
        # m3Show.Histogram: {"inputImg": "asfasdf"},
      

        m3Mask.mask: {"eye": "asdfasdf", "img":"iris", "mask":"manyPolyMask", "dest": "irisJustPolyMasked"},  
      #  retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
      #   m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
       #  m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 3, "show": True},
       #  m3F.getRed: {"inputImg": "ignorethis", "show": True},
    #   m3Edge.canny: {"inputImg": "asdfasdf", "thresh1": 100, "thresh2": 200},
    #    m3Niels.storeAttr: {"photo": "asdf", "eyeAttr": ""}
    
    
   #     m3Mask.placeEyesInFull("photo": "blabla", "fullImgAttr": "originalImage", "eyeAttr":  )
         }



postFunctions = {
   #
    
    
    
    #m3Niels.exportToFolder: {"parent": "Eye", "fileName": "image"},
    m3Batch.loadMasksForComparison: {"maskFolder": "PICTURES/five_mask/"}, # five_mask single_masked
   # m3Comparison.batchcc: {},    
  #  m3Mask.makeFullMask: {},
    m3Comparison.pixelcomparison: {},
    m3Batch.generateComparison: {"outputName":
                         "newdataset-fixedhohg", 
                         
                             "attrs": 
                                 ["image", "houghOutline", "irisJustPolyMasked", "manyPolyMask", "iris" ],
                                 "folderName": "nielstesting-easy-5", "exportFullMask": False, "CSV": True,
                                 "settings": [preFunctions, fArray, irisArray]
                            }, 
}


kMeanList = [2,5,30]

for index in range(0,(len(kMeanList))):
    print(index)
    RCparams = fArray[m3Color.reduceColor]
#    print(params)
    
    RCparams["n_colors"] = kMeanList[index]
    print("changed", RCparams)
    GCParams = postFunctions[m3Batch.generateComparison]
    GCParams["folderName"] = "actual_five_easy_w_colors_" + str(kMeanList[index])
    print(GCParams)
  #  GCParams = GCParams["foldername"]
 #   print( GCParams["foldername"])
    m3Batch.photoBatch("PICTURES/five/", fArray, debug=True, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)

#pa = m3Batch.photoBatch("PICTURES/single/", fArray, debug=True, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
# Test_set_easy single Test_set_hard five
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0
# changed {'inputImg': 'ignorethis', 'n_colors': 2, 'show': True}
# {'outputName': 'newdataset-fixedhohg', 'attrs': ['image', 'houghOutline', 'irisJustPolyMasked', 'manyPolyMask', 'iris'], 'folderName': 'actual_five_easy_w_colors_2', 'exportFullMask': False, 'CSV': True, 'settings': [{<function findEyes at 0x1c24833c80>: {'show': True, 'division': 8}, <function findEyes2 at 0x1c255d88c8>: {'show': True, 'division': 8}}, {<function medianFilter at 0x1c21535d08>: {'inputImg': 'ignore', 'kernelSize': 5, 'show': True}, <function runMSRCP at 0x1c21535e18>: {'inputImg': 'ignorethis', 'show': True}, <function reduceColor at 0x1c21542510>: {'inputImg': 'ignorethis', 'n_colors': 2, 'show': True}, <function getRed at 0x11c1f51e0>: {'inputImg': 'ignorethis', 'show': True}, <function denoise_tv_chambolle at 0x11cf968c8>: {'inputImg': 'ignorethis', 'weight': 0.1, 'eps': 0.0002, 'n_iter_max': 200, 'multichannel': True, 'show': False}, <function makePolyMask at 0x1c3551a488>: {'photo': 'asdfasdf'}, <function makeManyPolyMask at 0x1c3551a510>: {'photo': 'asdfasdf'}, <function applyPolyMask at 0x1c3551a2f0>: {'eye': 'asdfasdf'}, <function findCircle at 0x1c21508ae8>: {'eye': 'ignorethis', 'resolution': 1, 'min_dist': 100, 'param_1': 200, 'param_2': 10, 'min_radius_width_divider': 7, 'max_radius_width_divider': 5.5, 'show': True}, <function makeCircularMask at 0x1c24023950>: {'photo': 'asdfasdf'}, <function makeCircularOutline at 0x1c22cd4510>: {'photo': 'asdfasd', 'dest': 'houghOutline'}, <function applyCircMask at 0x1c3551a378>: {'photo': 'asdfasdf'}}, {<function mask at 0x1c3551a1e0>: {'eye': 'asdfasdf', 'img': 'iris', 'mask': 'manyPolyMask', 'dest': 'irisJustPolyMasked'}}]}
# **********************************************************************
# **********************************************************************
# DOING PRE FUNCIONS\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  findEyes <built-in method __dir__ of function object at 0x1c24833c80>
# function.__name__  in pre:  findEyes2 <built-in method __dir__ of function object at 0x1c255d88c8>
# **********************************************************************
# **********************************************************************
# DOING FUNCION ARRAY\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  medianFilter
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-ac02ed85ff66> in <module>
#     137   #  GCParams = GCParams["foldername"]
#     138  #   print( GCParams["foldername"])
# --> 139     m3Batch.photoBatch("PICTURES/five/", fArray, debug=True, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
#     140
#     141 #pa = m3Batch.photoBatch("PICTURES/single/", fArray, debug=True, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
#
# ~/School/MED3/P3/Code/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Batch.py in photoBatch(ins, functionArray, postArray, preArray, irisArray, debug, debugIris)
#     134                     for eye in face.eyes:
#     135                         print(doingFor)
# --> 136                         function(getattr(eye, str(doingFor)), **params)
#     137         # photo = iterFunction(photo, functionArray)
#     138
#
# AttributeError: 'Eye' object has no attribute 'None'

# %%
# TP, FN, FP

import csv

with open('innovators.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["SN", "Name", "Contribution"])
    writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
    writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
    writer.writerow([3, "Guido van Rossum", "Python Programming"])
    
    
import csv   
fields=['first','second','third']
with open(r'name', 'a') as f:
    writer = csv.writer(f)
    writer.writerow(fields)
