# %%
from matplotlib import pyplot as plt
plt.show()
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast
from M3 import m3Niels as m3Niels
from M3 import m3Class, m3Color, m3Size, m3i, m3Show, m3Edge
#from M3 import m3ReduceAmountsOfColor



# pre-stuff

preFunctions = {
    
         m3Face.findEyes: {"show": True, "division": 8},
         m3Face.findEyes2: {"show": True, "division": 8}

    
    #    m3Niels.fakeEyes: {} # pc boys u use dis, ( but then u can't use generateComparison)
}







fArray = {
        m3MedianFilter.medianFilter: {"inputImg": "ignore", "kernelSize": 5, "show": True},
        retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
        m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 12, "show": True},
        m3F.getRed: {"inputImg": "ignorethis", "show": True},
        #m3Contrast.contrast: {"inputImg": "ignore", "show": False},
        m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
#       m3Size.makeSmaller: {"eye": "asdfasf", "show": True, "scale": 6},
    
       # m3Show.Histogram: {"inputImg": "asfasdf"},
    
    
        m3Mask.makePolyMask: {"photo": "asdfasdf"},
        m3Mask.applyPolyMask: {"eye": "asdfasdf"}, 
    
        # 194 
        m3Mask.makeManyPolyMask: {"photo": "asdfasdf"}, 
    
    
        m3HoughCircle.findCircle: {"eye": "ignorethis", "resolution": 1, "min_dist": 100, "param_1": 200, "param_2": 10, 
                                    "min_radius_width_divider": 7, "max_radius_width_divider": 5.5, "show": True},
        m3Mask.makeCircularMask: {"photo": "asdfasdf"},

         m3Mask.applyCircMask: {"photo": "asdfasdf"}, 
            #m3i.i: {"eye": "afsadf"}
    
         }



# IRIS

#          _ . - = - . _
#        . "  \  \   /  /  " .
#      ,  \                 /  .
#    . \   _,.--~=~"~=~--.._   / .
#   ;  _.-"  / \ !   ! / \  "-._  .
#  / ,"     / ,` .---. `, \     ". \
# /.'   `~  |   /:::::\   |  ~`   '.\
# \`.  `~   |   \:::::/   | ~`  ~ .'/
#  \ `.  `~ \ `, `~~~' ,` /   ~`.' /
#   .  "-._  \ / !   ! \ /  _.-"  .
#    ./    "=~~.._  _..~~=`"    \.
#      ,/         ""          \,
#        . _/             \_ . 
#           " - ./. .\. - "

irisArray = {
        # m3Show.Histogram: {"inputImg": "asfasdf"},
        # retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
        # m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
        # m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 3, "show": True},
        # m3F.getRed: {"inputImg": "ignorethis", "show": True},

        m3Mask.mask: {"eye": "asdfasdf", "img":"iris", "mask":"manyPolyMask", "dest": "iris"},  
    #   m3Edge.canny: {"inputImg": "asdfasdf", "thresh1": 100, "thresh2": 200},
    #    m3Niels.storeAttr: {"photo": "asdf", "eyeAttr": ""}
    
    
   #     m3Mask.placeEyesInFull("photo": "blabla", "fullImgAttr": "originalImage", "eyeAttr":  )
         }



postFunctions = {
   #
    
    
    
    #m3Niels.exportToFolder: {"parent": "Eye", "fileName": "image"},
    
    
    
    m3Niels.
    generateComparison: {"outputName":
                         "newdataset-fixedhohg", 
                         
                             "attrs": 
                                 ["image", "iris"]
                            }, 
}




pa = m3Niels.photoBatch("PICTURES/Test_set_hard/", fArray, debug=False, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
# Test_set_easy single
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# **********************************************************************
# **********************************************************************
# DOING PRE FUNCIONS\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  findEyes
#
# x y  229 170
# x y  239 164
# x y  250 163
# x y  264 169
# x y  251 171
# x y  239 171
# x y  317 167
# x y  329 161
# x y  340 161
# x y  351 166
# x y  341 167
# x y  329 167
# x y  131 259
# x y  139 252
# x y  151 253
# x y  161 261
# x y  150 263
# x y  138 263
# x y  211 267
# x y  224 259
# x y  237 262
# x y  249 271
# x y  236 273
# x y  222 271
# x y  181 195
# x y  187 191
# x y  196 194
# x y  204 203
# x y  194 203
# x y  185 201
# x y  242 211
# x y  252 206
# x y  263 209
# x y  271 216
# x y  261 218
# x y  250 216
# x y  145 116
# x y  153 113
# x y  161 115
# x y  167 123
# x y  159 122
# x y  151 120
# x y  202 130
# x y  209 124
# x y  216 125
# x y  221 132
# x y  215 133
# x y  208 132
# x y  339 172
# x y  349 166
# x y  361 165
# x y  370 172
# x y  361 174
# x y  349 174
# x y  414 170
# x y  423 162
# x y  433 161
# x y  440 167
# x y  434 171
# x y  424 171
# x y  199 290
# x y  205 286
# x y  211 287
# x y  216 291
# x y  211 292
# x y  205 292
# x y  239 290
# x y  243 285
# x y  248 285
# x y  251 288
# x y  248 290
# x y  243 290
# x y  58 209
# x y  71 200
# x y  87 201
# x y  100 214
# x y  85 219
# x y  69 218
# x y  159 215
# x y  174 201
# x y  191 201
# x y  205 209
# x y  193 218
# x y  175 218
# x y  215 243
# x y  226 239
# x y  238 239
# x y  251 246
# x y  238 247
# x y  226 246
# x y  310 249
# x y  325 242
# x y  338 243
# x y  350 249
# x y  337 252
# x y  324 251
# x y  231 259
# x y  241 253
# x y  252 252
# x y  260 258
# x y  251 261
# x y  241 262
# x y  298 257
# x y  308 252
# x y  317 251
# x y  323 257
# x y  318 260
# x y  308 260
# x y  374 177
# x y  379 172
# x y  388 173
# x y  396 180
# x y  387 181
# x y  379 180
# x y  429 179
# x y  436 172
# x y  445 171
# x y  453 175
# x y  446 179
# x y  437 180
# x y  113 175
# x y  118 171
# x y  124 171
# x y  129 175
# x y  124 177
# x y  118 177
# x y  154 174
# x y  159 170
# x y  164 170
# x y  169 173
# x y  165 175
# x y  159 176
# x y  245 337
# x y  252 333
# x y  262 332
# x y  269 337
# x y  261 340
# x y  252 341
# x y  302 334
# x y  310 328
# x y  319 327
# x y  327 330
# x y  320 335
# x y  311 336
# x y  189 200
# x y  198 196
# x y  209 196
# x y  219 204
# x y  208 205
# x y  197 204
# x y  261 206
# x y  270 199
# x y  280 199
# x y  288 203
# x y  280 207
# x y  271 207
# x y  291 160
# x y  299 153
# x y  309 153
# x y  318 160
# x y  309 163
# x y  299 164
# x y  360 159
# x y  370 151
# x y  381 151
# x y  389 157
# x y  382 161
# x y  371 161
# x y  146 149
# x y  153 142
# x y  161 141
# x y  169 147
# x y  161 149
# x y  153 150
# x y  208 142
# x y  216 136
# x y  227 135
# x y  236 140
# x y  227 143
# x y  217 144
# x y  136 225
# x y  143 221
# x y  152 220
# x y  160 225
# x y  152 226
# x y  144 227
# x y  202 223
# x y  210 217
# x y  219 218
# x y  228 222
# x y  220 224
# x y  211 224
# x y  343 201
# x y  347 196
# x y  352 196
# x y  358 199
# x y  352 201
# x y  347 201
# x y  383 198
# x y  388 194
# x y  394 194
# x y  399 198
# x y  394 199
# x y  388 199
# x y  72 145
# x y  76 142
# x y  83 143
# x y  89 147
# x y  82 148
# x y  76 148
# x y  121 147
# x y  127 143
# x y  136 144
# x y  145 145
# x y  137 149
# x y  128 149
#  found no faces in this picture\]
# x y  318 124
# x y  325 120
# x y  334 120
# x y  342 126
# x y  333 128
# x y  324 128
# x y  377 128
# x y  385 124
# x y  394 124
# x y  401 129
# x y  394 131
# x y  385 131
# function.__name__  in pre:  findEyes2
# **********************************************************************
# **********************************************************************
# DOING FUNCION ARRAY\]
# **********************************************************************
# **********************************************************************
# function name medianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# function name runMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# function name reduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# function name getRed\]
# Doing an inputimg as eye.wip withgetRed\]
# Doing an inputimg as eye.wip withgetRed\]
# function name denoise_tv_chambolle\]
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# /Users/n/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# function name makePolyMask\]
# Doing an photo withmakePolyMask\]
# function name applyPolyMask\]
# Doing an eye withapplyPolyMask\]
# function name makeManyPolyMask\]
# Doing an photo withmakeManyPolyMask\]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-38220df9f694> in <module>
#     121
#     122
# --> 123 pa = m3Niels.photoBatch("PICTURES/Test_set_hard/", fArray, debug=False, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=irisArray)
#     124 # Test_set_easy single
#     125
#
# ~/School/MED3/P3/Code/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Niels.py in photoBatch(ins, functionArray, postArray, preArray, irisArray, debug, debugIris)
#     205         # for face in photo.faces:
#     206         #     print(face)
# --> 207         photo = iterFunction(photo, functionArray)
#     208
#     209
#
# ~/School/MED3/P3/Code/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Niels.py in iterFunction(photo, functionArray)
#      33             m3F.printBlue("Doing an photo with" + currentFunctionName)
#      34             functionParams["photo"] = photo
# ---> 35             photo = function(**functionParams)
#      36         if ("eye" in functionParams):
#      37             m3F.printBlue(("Doing an eye with" + currentFunctionName))
#
# ~/School/MED3/P3/Code/P3-G306/STRUCTURE/NOTEBOOKS/M3/m3Mask.py in makeManyPolyMask(photo, show)
#     161
#     162             # print("manyLandmarkPoints", eye.manyLandmarkPoints)
# --> 163             polyMask = cv2.fillPoly(polyMask, np.int_([eye.manyLandmarkPoints]), (255, 255, 255))
#     164             # m3Show.imshow(polyMask, "POLYMASK")
#     165             # epm = m3Class.Eye(np.asarray(pil_image.crop(left)), left, lEyeCoor)
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/drawing.cpp:2403: error: (-215:Assertion failed) p.checkVector(2, CV_32S) >= 0 in function 'fillPoly'

# %%
m3Niels.generateComparison(pa, fileName="iris")

# %%
#print(pa[0].faces[0].eyes[0].__dict__.items())
from M3 import m3Show 
print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aab4164778f0> in <module>
#       1 #print(pa[0].faces[0].eyes[0].__dict__.items())
#       2 from M3 import m3Show
# ----> 3 print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
#
# NameError: name 'pa' is not defined

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast, semi_circles, m3Color
from M3 import m3Niels as m3Niels
from M3 import m3Class
