# %%
from matplotlib import pyplot as plt
plt.show()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast
from M3 import m3Niels as m3Niels
from M3 import m3Class, m3Color, m3Size, m3i, m3Show, m3Edge
#from M3 import m3ReduceAmountsOfColor



fArray = {
             m3MedianFilter.medianFilter: {"inputImg": "ignore", "kernelSize": 5, "show": True},
         retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
         m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 12, "show": True},
         m3F.getRed: {"inputImg": "ignorethis", "show": True},
         #m3Contrast.contrast: {"inputImg": "ignore", "show": False},
         m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
   #   
#            m3Size.makeSmaller: {"eye": "asdfasf", "show": True, "scale": 6},
            m3Show.Histogram: {"inputImg": "asfasdf"},
         m3Mask.makePolyMask: {"photo": "asdfasdf"}, # this should probably NOT be here, but in the fArray - will change
        m3Mask.applyPolyMask: {"eye": "asdfasdf"}, # same for this
             m3Mask.makeManyPolyMask: {"photo": "asdfasdf"}, # this should probably NOT be here, but in the fArray - will change
       m3HoughCircle.findCircle: {"eye": "ignorethis", "resolution": 1, "min_dist": 100, "param_1": 200, "param_2": 10, 
                                    "min_radius_width_divider": 7, "max_radius_width_divider": 5.5, "show": True},
      m3Mask.makeCircularMask: {"photo": "asdfasdf"}, # this should probably NOT be here, but in the fArray - will change
     m3Mask.applyCircMask: {"photo": "asdfasdf"}, # same for this
            #m3i.i: {"eye": "afsadf"}
    
         }

iArray = {
         m3Show.Histogram: {"inputImg": "asfasdf"},
    # retinexRunnable.runMSRCP: {"inputImg": "ignorethis", "show": True},
             m3tv.denoise_tv_chambolle: {"inputImg": "ignorethis", "weight": 0.1,"eps": 0.0002,"n_iter_max": 200, "multichannel": True, "show": False},
         m3Color.reduceColor: {"inputImg": "ignorethis", "n_colors": 3, "show": True},
         m3F.getRed: {"inputImg": "ignorethis", "show": True},
        m3Edge.canny: {"inputImg": "asdfasdf", "thresh1": 100, "thresh2": 200},
    

         }

# this is functions used after all the processing
postFunctions = {
  #  m3Mask.makeCircularMask: {}, # this should probably NOT be here, but in the fArray - will change
 #   m3Mask.applyCircMask: {}, # same for this
   # m3Niels.exportToFolder: {"parent": "Eye", "fileName": "image"},
m3Niels.generateComparison: {"outputName": "newdataset-fixedhohg", "fileName": "houghOutline"}, # does not work for PC boys, but u should be able to change it a bit to work.
}


# pre-stuff
#totally awesome comments
preFunctions = {
     m3Face.findEyes: {"show": True, "division": 8},
         m3Face.findEyes2: {"show": True, "division": 8}
    #    m3Niels.fakeEyes: {} # pc boys u use dis, ( but then u can't use generateComparison)
}


#pa = m3Niels.photoBatch("PICTURES//", fArray, debug=True, preArray=preFunctions, postArray=postFunctions, irisArray=iArray)
#pa = m3Niels.photoBatch("PICTURES/IdealSet/", fArray, debug=True, preArray=preFunctions, postArray=postFunctions, irisArray=iArray)

pa = m3Niels.photoBatch("PICTURES/IdealSet/", fArray, debug=False, debugIris=True, preArray=preFunctions, postArray=postFunctions, irisArray=iArray)
#" PICTURES/Eyes/Eyes_set1/ Test_set_easy "
# "PICTURES/InputPictures/xsingle/"

#PICTURES/InputPictures/Set1
#PICTURES/Eyes/Eyes_set1/
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# **********************************************************************
# **********************************************************************
# DOING PRE FUNCIONS\]
# **********************************************************************
# **********************************************************************
# function.__name__  in pre:  findEyes
#
# x y  434 367
# x y  454 357
# x y  478 359
# x y  499 380
# x y  475 384
# x y  450 382
# x y  590 381
# x y  609 360
# x y  634 358
# x y  654 369
# x y  637 383
# x y  613 385
# x y  436 281
# x y  448 275
# x y  462 274
# x y  474 283
# x y  462 286
# x y  448 286
# x y  526 282
# x y  537 272
# x y  551 271
# x y  562 277
# x y  552 283
# x y  538 283
# x y  164 194
# x y  176 188
# x y  191 187
# x y  203 195
# x y  190 198
# x y  176 199
# x y  266 194
# x y  280 186
# x y  294 187
# x y  305 193
# x y  294 197
# x y  280 196
# function.__name__  in pre:  findEyes2
# dets rectangles[[(384, 277) (705, 598)]]
# Number of faces detected: 1
# kkkk 0
# cropRect [3368, 2752, 4096, 3176]
# cropRect [4616, 2760, 5336, 3184]
# dets rectangles[[(407, 222) (593, 407)]]
# Number of faces detected: 1
# kkkk 0
# cropRect [3424, 2128, 3856, 2352]
# cropRect [4152, 2112, 4552, 2320]
# dets rectangles[[(117, 118) (340, 341)]]
# Number of faces detected: 1
# kkkk 0
# cropRect [1248, 1432, 1688, 1656]
# cropRect [2064, 1424, 2504, 1640]
# **********************************************************************
# **********************************************************************
# DOING FUNCION ARRAY\]
# **********************************************************************
# **********************************************************************
# function name medianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# function name runMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# function name reduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# function name getRed\]
# Doing an inputimg as eye.wip withgetRed\]
# Doing an inputimg as eye.wip withgetRed\]
# function name denoise_tv_chambolle\]
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# /Users/n/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# function name Histogram\]
# Doing an inputimg as eye.wip withHistogram\]
# Doing an inputimg as eye.wip withHistogram\]
# function name makePolyMask\]
# Doing an photo withmakePolyMask\]
# EYE COOR [(3472, 2936), (3632, 2856), (3824, 2872), (3992, 3040), (3800, 3072), (3600, 3056)]
# EYE COOR [(4720, 3048), (4872, 2880), (5072, 2864), (5232, 2952), (5096, 3064), (4904, 3080)]
# function name applyPolyMask\]
# Doing an eye withapplyPolyMask\]
# function name makeManyPolyMask\]
# Doing an photo withmakeManyPolyMask\]
# function name findCircle\]
# Doing an eye withfindCircle\]
# ***************************************************************************************
# 104
# ***************************************************************************************
# 102
# function name makeCircularMask\]
# Doing an photo withmakeCircularMask\]
# function name applyCircMask\]
# Doing an photo withapplyCircMask\]
# function name medianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# function name runMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# function name reduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# function name getRed\]
# Doing an inputimg as eye.wip withgetRed\]
# Doing an inputimg as eye.wip withgetRed\]
# function name denoise_tv_chambolle\]
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# /Users/n/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# function name Histogram\]
# Doing an inputimg as eye.wip withHistogram\]
# Doing an inputimg as eye.wip withHistogram\]
# function name makePolyMask\]
# Doing an photo withmakePolyMask\]
# EYE COOR [(3488, 2248), (3584, 2200), (3696, 2192), (3792, 2264), (3696, 2288), (3584, 2288)]
# EYE COOR [(4208, 2256), (4296, 2176), (4408, 2168), (4496, 2216), (4416, 2264), (4304, 2264)]
# function name applyPolyMask\]
# Doing an eye withapplyPolyMask\]
# function name makeManyPolyMask\]
# Doing an photo withmakeManyPolyMask\]
# function name findCircle\]
# Doing an eye withfindCircle\]
# ***************************************************************************************
# 61
# ***************************************************************************************
# 57
# function name makeCircularMask\]
# Doing an photo withmakeCircularMask\]
# function name applyCircMask\]
# Doing an photo withapplyCircMask\]
# function name medianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# Doing an inputimg as eye.wip withmedianFilter\]
# function name runMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# Doing an inputimg as eye.wip withrunMSRCP\]
# function name reduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# Doing an inputimg as eye.wip withreduceColor\]
# function name getRed\]
# Doing an inputimg as eye.wip withgetRed\]
# Doing an inputimg as eye.wip withgetRed\]
# function name denoise_tv_chambolle\]
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# Doing an inputimg as eye.wip withdenoise_tv_chambolle\]
# function name Histogram\]
# Doing an inputimg as eye.wip withHistogram\]
# /Users/n/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Doing an inputimg as eye.wip withHistogram\]
# function name makePolyMask\]
# Doing an photo withmakePolyMask\]
# EYE COOR [(1312, 1552), (1408, 1504), (1528, 1496), (1624, 1560), (1520, 1584), (1408, 1592)]
# EYE COOR [(2128, 1552), (2240, 1488), (2352, 1496), (2440, 1544), (2352, 1576), (2240, 1568)]
# function name applyPolyMask\]
# Doing an eye withapplyPolyMask\]
# function name makeManyPolyMask\]
# Doing an photo withmakeManyPolyMask\]
# function name findCircle\]
# Doing an eye withfindCircle\]
# ***************************************************************************************
# 62
# ***************************************************************************************
# 62
# function name makeCircularMask\]
# Doing an photo withmakeCircularMask\]
# function name applyCircMask\]
# Doing an photo withapplyCircMask\]
# **********************************************************************
# **********************************************************************
# DOING IRIS FUNCION ARRAY\]
# **********************************************************************
# **********************************************************************
# function name Histogram\]
# function name denoise_tv_chambolle\]
# function name reduceColor\]
# function name getRed\]
# function name canny\]
# generateComparison

# %%
m3Niels.generateComparison(pa, fileName="iris")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ca66e49398f3> in <module>
# ----> 1 m3Niels.generateComparison(pa, fileName="iris")
#
# NameError: name 'pa' is not defined

# %%
#print(pa[0].faces[0].eyes[0].__dict__.items())
from M3 import m3Show 
print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aab4164778f0> in <module>
#       1 #print(pa[0].faces[0].eyes[0].__dict__.items())
#       2 from M3 import m3Show
# ----> 3 print(m3Show.imshow(pa[2].faces[0].eyes[0].iris, "IRIS"))
#
# NameError: name 'pa' is not defined

# %%
from matplotlib import pyplot as plt
import cv2, sys
sys.path.append("/M3")
from M3 import m3F as m3F
from M3 import m3Face, m3tv
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3Batch as m3Batch
from M3 import m3Pre as m3Pre
from M3 import m3Mask as m3Mask
from M3 import m3HoughCircle as m3HoughCircle
from M3 import m3MedianFilter, m3Denoising, retinexRunnable, m3Contrast, semi_circles, m3Color
from M3 import m3Niels as m3Niels
from M3 import m3Class
