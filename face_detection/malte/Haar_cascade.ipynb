# %%
import numpy as np
import cv2

# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades

#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')


img = cv2.imread('two_people.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        crop = roi_color[ey:ey+eh, ex:ex+ew]
        name = 'crop'
        cv2.imshow(name,crop)
        

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

def findEyes(inputIm):
    # multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades

    #https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    #https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

    

    gray = cv2.cvtColor(inputIm, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        img = cv2.rectangle(inputIm,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
     
        roi_color = inputIm[y:y+h, x:x+w]
        plt.imshow(roi_color)
        plt.show()
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
            crop = eyes[ey:ey+eh, ex:ex+ew]

            return [np.asarray(crop),np.asarray(crop)];

# %%
import glob
from PIL import Image
import cv2 
import numpy as np
import types
inputFolder = "input_images/"
outputFolder = "output_images/"

inputImages=glob.glob(inputFolder + "*.jpeg")

for imagePath in inputImages:
    #imgIn = Image.open(image)
    imgIn = cv2.imread(imagePath)
    imagePath = imagePath.replace(inputFolder, "")
    imagePath = outputFolder + imagePath
    # DO STUFF TO ALL IMAGES BELOW
    # *************************
    print("imgIn type:", type(imgIn))
    imgOut = findEyes(imgIn)
    
    print("imgOut type:", type(imgOut))
   
        #imgOut = np.asarray(imgOut)
    # *************************
    #if isinstance(imgOut, types.ListType):
    if (type(imgOut) == type(list())):
        print("was list")
        #for i in imgOut:
        #for i = 1 to 
        #for (i = 1; i <= imgOut.len(); i++)
         #   
        eyes = iter(imgOut)
        imagePath = imagePath.replace(".", "_Left.")
        cv2.imwrite(imagePath,next(eyes))
        imagePath = imagePath.replace("_Left.", "_Right.")
        cv2.imwrite(imagePath,next(eyes))
    else:
        cv2.imwrite(imagePath,imgOut)
# Out:
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'NoneType'>
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'NoneType'>
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'NoneType'>
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'list'>
# was list
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'NoneType'>
# imgIn type: <class 'numpy.ndarray'>
# imgOut type: <class 'NoneType'>
# ...
