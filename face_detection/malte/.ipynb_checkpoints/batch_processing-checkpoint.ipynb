# %% [markdown]
# ### run first cell first, otherwise plt.show() might not work = no images showing

# %%
from matplotlib import pyplot as plt
plt.show()

# %% [markdown]
# # FIND FACES

# %%
import glob
from PIL import Image
import cv2 
import numpy as np
import types
import os
import m3Face, m3Iris, m3F
from matplotlib import pyplot as plt
inputFolder = "input_images/"
outputFolder = "output_eyes/"
eyesExpected = 37   # Manually type in the number of eyes expected from inputFolder
eyesFound = 0

inputImages=glob.glob(inputFolder + "*.j*")

for imagePath in inputImages:

    # if outfolder does not exist, create it
    if not (os.path.exists(outputFolder)):
            os.mkdir(outputFolder)
            print("output folder did not exist,", outputFolder, "created.")
    # read input image
#    imgIn = cv2.imread()
    

    
    # DO STUFF TO ALL IMAGES BELOW
    # *************************

    imgOut = m3Face.findEyes(imagePath)
    # *************************

        #change imagePath from input folder to output folder
    imagePath = imagePath.replace(inputFolder, "")
    inputName = imagePath.replace(".png", "")
    imagePath = outputFolder + inputName
    
    if (type(imgOut) == type(list()) and len(imgOut) > 0):
        eyes = iter(imgOut) # used to iterate through an array. the output of first next() is the first element of array, and so on
        eyeCount = 1
        faceCount = 1
        
        for i in imgOut:
            LR = "Left"
            if ((eyeCount % 2) == 0):
                LR = "Right"
            ouputImg = "{}_Face_{}_{}.png".format(imagePath,str(faceCount),LR)
            cv2.imwrite(ouputImg,next(eyes))
            eyesFound += 1
            
            if ((eyeCount % 2) == 0):
                faceCount += 1
            eyeCount += 1

m3F.printBlue("Found {}% of eyes in the images".format(eyesFound/eyesExpected*100))
# Out:
# output folder did not exist, output_eyes2/ created.
# proccesing set2/5991451389_16a2ba1419_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/6431446393_14843174cc_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/a4927-_DGW0242.png
#  found no faces in this picture\]
# eyeImages <class 'list'> 0
# proccesing set2/5832043559_778063899f_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/3641009730_f3800ff77f_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/8863596917_7e2a5d38a1_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/8089433130_8bec7e35ac_o.png
# tilted left
# eyeImages <class 'list'> 2
# proccesing set2/4057711393_cf0cb75243_o.png
# tilted left
# eyeImages <class 'list'> 2
# proccesing set2/3574734014_bb18af843a_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/4081454510_a09c243cfd_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/4583420392_1056f22531_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/3445051137_e4ebf80662_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/8108242905_f7bbebe304_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/7738161882_323084ae4a_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/2328140094_3005a149d4_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/a4743-_DGW0316.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/6053146034_73da2b9c21_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/348625753_a09d77183a_o.png
# tilted left
# eyeImages <class 'list'> 2
# proccesing set2/3808010112_890383a02f_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/6310273866_0fde1fe961_o.png
# tilted right
# eyeImages <class 'list'> 2
# proccesing set2/a4853-_DGW0247.png
# tilted right
# eyeImages <class 'list'> 2
# Found 632.4324324324325% of eyes in the images\]

# %% [markdown]
# # FIND IRIS

# %%
from matplotlib import pyplot as plt
plt.show()

# %%
import glob
from PIL import Image
import cv2 
import numpy as np
import types
import os
import m3Iris, m3F
inputFolder = "output_eyes/"
outputFolder = "irises/"
#irisesExpected = m3F.filecount(inputFolder)
irisesExpected = 32
irisesFound = 0


inputImages=glob.glob(inputFolder + "*.j*")

for imagePath in inputImages:
    
    # if outfolder does not exist, create it
    if not (os.path.exists(outputFolder)):
            os.mkdir(outputFolder)
            print("output folder did not exist,", outputFolder, "created.")
    

    # DO STUFF TO ALL IMAGES BELOW (SENDS IMAGEPATH TO YOUR FUNCTIONS)
    # *************************
    if (m3F.evalSize(imagePath,10,10)):
        imgOut = m3Iris.findCircle(imagePath)
    else:
        print("****************************************************************************************************************")
        m3F.printRed("####IMAGE TOOO SMALL###")
        continue;
        # *************************

     #change imagePath from input folder to output folder
    imagePath = imagePath.replace(inputFolder, "")
    imagePath = outputFolder + imagePath
    print("imagePath", imagePath)
    
    
    if (type(imgOut) == type(list())):
        print("length",len(imgOut))
        #print("was list")
        # if output 
        eyes = iter(imgOut) # used to iterate thru an array. the output of first next() is the first element of array, and so on
        
        #cv2.imwrite(imagePath,next(eyes))
        irisesFound += 1
    else:
        if not(type(imgOut) == type(None)):
            cv2.imwrite(imagePath,imgOut)
            irisesFound += 1
        #else:   
            #m3F.printRed("IMAGE NULL")

print("irises found:", irisesFound)
m3F.printBlue("Found {}% of irises in the images".format(irisesFound/irisesExpected*100))
# Out:
# ***************************************************************************************
# proccesing output_eyes/photo3_Face_1_Right.jpeg
# image height:  25
# circle: 40 16
# pixel: 66
# imagePath irises/photo3_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo19_Face_1_Right.jpeg
# image height:  99
# circle: 84 42
# pixel: 0
# circle radius:  34
# CIRCLES FOUND^^^\]
# imagePath irises/photo19_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo6_Face_1_Right.jpeg
# image height:  31
# circle: 22 12
# pixel: 16
# imagePath irises/photo6_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo16_Face_1_Left.jpeg
# image height:  26
# circle: 36 14
# pixel: 20
# imagePath irises/photo16_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo2_Face_1_Right.jpeg
# image height:  25
# NO CIRCLES FOUND^^^\]
# imagePath irises/photo2_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo12_Face_1_Left.jpeg
# image height:  95
# circle: 96 40
# pixel: 0
# circle radius:  33
# CIRCLES FOUND^^^\]
# imagePath irises/photo12_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo18_Face_1_Right.jpeg
# image height:  94
# circle: 94 36
# pixel: 0
# circle radius:  31
# CIRCLES FOUND^^^\]
# imagePath irises/photo18_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo19_Face_1_Left.jpeg
# image height:  104
# circle: 90 44
# pixel: 0
# circle radius:  33
# CIRCLES FOUND^^^\]
# imagePath irises/photo19_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo4_Face_1_Right.jpeg
# image height:  48
# NO CIRCLES FOUND^^^\]
# imagePath irises/photo4_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo17_Face_1_Left.jpeg
# image height:  64
# circle: 68 18
# pixel: 0
# circle radius:  24
# CIRCLES FOUND^^^\]
# imagePath irises/photo17_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo13_Face_1_Left.jpeg
# image height:  66
# circle: 58 30
# pixel: 0
# circle radius:  20
# CIRCLES FOUND^^^\]
# imagePath irises/photo13_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo18_Face_1_Left.jpeg
# image height:  94
# circle: 88 38
# pixel: 0
# circle radius:  31
# CIRCLES FOUND^^^\]
# imagePath irises/photo18_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo4_Face_1_Left.jpeg
# image height:  44
# circle: 66 26
# pixel: 171
# imagePath irises/photo4_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo8_Face_1_Left.jpeg
# image height:  26
# circle: 24 10
# pixel: 3
# circle radius:  8
# CIRCLES FOUND^^^\]
# imagePath irises/photo8_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo16_Face_1_Right.jpeg
# image height:  30
# circle: 26 14
# pixel: 255
# imagePath irises/photo16_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo14_Face_1_Left.jpeg
# image height:  74
# circle: 68 26
# pixel: 34
# imagePath irises/photo14_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo9_Face_1_Right.jpeg
# image height:  64
# circle: 56 26
# pixel: 0
# circle radius:  18
# CIRCLES FOUND^^^\]
# imagePath irises/photo9_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo3_Face_1_Left.jpeg
# image height:  25
# circle: 34 12
# pixel: 186
# imagePath irises/photo3_Face_1_Left.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo13_Face_1_Right.jpeg
# image height:  67
# circle: 52 34
# pixel: 0
# circle radius:  19
# CIRCLES FOUND^^^\]
# imagePath irises/photo13_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo17_Face_1_Right.jpeg
# image height:  63
# circle: 68 24
# pixel: 6
# circle radius:  21
# CIRCLES FOUND^^^\]
# imagePath irises/photo17_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo8_Face_1_Right.jpeg
# image height:  28
# circle: 32 12
# pixel: 3
# circle radius:  8
# CIRCLES FOUND^^^\]
# imagePath irises/photo8_Face_1_Right.jpeg
# ***************************************************************************************
# proccesing output_eyes/photo10_Face_1_Left.jpeg
# image height:  68
# circle: 60 26
# pixel: 0
# circle radius:  20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-255c28562c70> in <module>
#      26     # *************************
#      27     if (m3F.evalSize(imagePath,10,10)):
# ---> 28         imgOut = m3Iris.findCircle(imagePath)
#      29     else:
#      30         print("****************************************************************************************************************")
#
# ~/Documents/GitHub/P3-G306/face_detection/malte/m3Iris.py in findCircle(inputImg)
#      72                         plt.imshow(finalImg)
#      73                         plt.show()
# ---> 74                         m3F.gHist(img)
#      75                         m3F.printGreen("CIRCLES FOUND^^^")
#      76                         return cimg;
#
# ~/Documents/GitHub/P3-G306/face_detection/malte/m3F.py in gHist(imagePath)
#      53     for i in range(0, 256):
#      54         plt.bar(i, hist[i], alpha=0.3)
# ---> 55     plt.show()
#      56
#      57
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     261     """
#     262     global _show
# --> 263     return _show(*args, **kw)
#     264
#     265
#
# //anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <//anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# //anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#     571                 self._bind_draw_path_function(renderer) as draw_path:
#     572             path = self.get_path()
# --> 573             transform = self.get_transform()
#     574             tpath = transform.transform_path_non_affine(path)
#     575             affine = transform.get_affine()
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     732                  not directly access the transformation member variable.
#     733         """
# --> 734         x0, y0, x1, y1 = self._convert_units()
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt
plt.show()

# %%
import glob
import cv2 
import os

import m3Iris, m3F

inputFolder = "output_eyes/"
outputFolder = "irises/"
irisesExpected = m3F.filecount(inputFolder)
irisesFound = 0

inputImages=glob.glob(inputFolder + "*.j*")

for imagePath in inputImages:
    
    # if outfolder does not exist, create it
    if not (os.path.exists(outputFolder)):
            os.mkdir(outputFolder)
            print("output folder did not exist,", outputFolder, "created.")
    

    # DO STUFF TO ALL IMAGES BELOW (SENDS IMAGEPATH TO YOUR FUNCTIONS)
    # *************************
    if (m3F.evalSize(imagePath,10,10)):
        imgIn = cv2.imread(imagePath, 1)
        
        # IMAGE PROCESSING HERE:
        m3F.imshow(imgIn,"imgIn")
        imgOut = m3Iris.findCircle(imgIn)
        #imgMSRCP = retinexRunnable.runMSRCP(imagePath)
        
        (channel_b, channel_g, channel_r) = cv2.split(imgMSRCP)
        m3F.imshow(channel_r,"red")
        channel_r = cv2.medianBlur(channel_r, 9)
        m3F.imshow(channel_r,"red")
        imgMSRCP = cv2.merge((channel_b, channel_g, channel_r))
        m3F.imshow(imgMSRCP,"red blurred")
        imgMSRCP = cv2.medianBlur(imgMSRCP, 5)
        
        imgOut2 = m3Iris.findCircle(channel_r)
        imgOut2 = m3Iris.findCircle(imgMSRCP)
        
    else:
        print("****************************************************************************************************************")
        m3F.printRed("####IMAGE TOOO SMALL###")
        continue;
        # *************************

     #change imagePath from input folder to output folder
    imagePath = imagePath.replace(inputFolder, "")
    imagePath = outputFolder + imagePath
    #print("length",len(imgOut))
    
    if (type(imgOut) == type(list())):
        #print("was list")
        # if output 
        eyes = iter(imgOut) # used to iterate thru an array. the output of first next() is the first element of array, and so on
        
        #cv2.imwrite(imagePath,next(eyes))
        irisesFound += 1
    else:
        if not(type(imgOut) == type(None)):
            cv2.imwrite(imagePath,imgOut)
            irisesFound += 1
        #else:   
            #m3F.printRed("IMAGE NULL")
            
m3F.printBlue("Found {}% of irises in the images".format(irisesFound/irisesExpected*100))
# Out:
# ***************************************************************************************
# image height:  25
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-1b1c63e4da7d> in <module>
#      27         # IMAGE PROCESSING HERE:
#      28         m3F.imshow(imgIn,"imgIn")
# ---> 29         imgOut = m3Iris.findCircle(imgIn)
#      30         #imgMSRCP = retinexRunnable.runMSRCP(imagePath)
#      31
#
# ~/Documents/GitHub/P3-G306/face_detection/malte/m3Iris.py in findCircle(inputImg)
#      49         #plt.show()
#      50         print("image height: ", int(m3F.typeSwap(img).height))
# ---> 51         circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,120,param1=200,param2=10,minRadius=int(m3F.typeSwap(img).height/6),maxRadius=int(m3F.typeSwap(img).height/2.5))
#      52
#      53
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/hough.cpp:1728: error: (-215:Assertion failed) !_image.empty() && _image.type() == CV_8UC1 && (_image.isMat() || _image.isUMat()) in function 'HoughCircles'
