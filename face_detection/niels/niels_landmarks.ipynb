# %%
# https://pysource.com/2019/03/12/face-landmarks-detection-opencv-with-python/
import cv2
import numpy as np
import dlib # pip install dlib (close anaconda first)



detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")


frame = cv2.imread("mikkel.jpg")
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

faces = detector(gray)
for face in faces:
    x1 = face.left()
    y1 = face.top()
    x2 = face.right()
    y2 = face.bottom()
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)

    landmarks = predictor(gray, face)


    for n in range(0, 68):
        print(landmarks.part(n))
        x = landmarks.part(n).x
        y = landmarks.part(n).y
        cv2.circle(frame, (x, y), 4, (255, 0, 0), -1)

    cv2.imshow("Frame", frame)
    cv2.imwrite("pikke2.jpg",frame)
# Out:
# (45, 46)
# (43, 69)
# (42, 93)
# (48, 115)
# (61, 133)
# (76, 148)
# (93, 163)
# (113, 174)
# (132, 174)
# (145, 167)
# (151, 152)
# (157, 136)
# (164, 119)
# (170, 104)
# (176, 87)
# (178, 70)
# (177, 55)
# (93, 51)
# (107, 47)
# (121, 47)
# (135, 48)
# (149, 53)
# (161, 50)
# (168, 45)
# (174, 40)
# (180, 36)
# (182, 37)
# (154, 61)
# (156, 75)
# (159, 89)
# (162, 103)
# (138, 109)
# (147, 112)
# (155, 114)
# (162, 111)
# (167, 106)
# (108, 62)
# (117, 61)
# (125, 59)
# (131, 61)
# (125, 65)
# (117, 66)
# (158, 56)
# (165, 52)
# (171, 51)
# (174, 53)
# (171, 57)
# (165, 57)
# (118, 134)
# (131, 131)
# (143, 129)
# (149, 130)
# (153, 127)
# (156, 126)
# (155, 127)
# (154, 135)
# (152, 140)
# (147, 143)
# (141, 144)
# (129, 141)
# (123, 133)
# (142, 133)
# (148, 133)
# (152, 131)
# (153, 129)
# (153, 130)
# (148, 133)
# (142, 134)

# %% [markdown]
# ![title](pikke2.jpg)
# ![title](mikkel.jpg)
