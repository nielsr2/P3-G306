# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

rows, cols =(3,3)
Kernel =[[0]*rows]*cols
print(Kernel)


img = mpimg.imread("noisePic.jpg")
imgplot = plt.imshow(img)
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]
