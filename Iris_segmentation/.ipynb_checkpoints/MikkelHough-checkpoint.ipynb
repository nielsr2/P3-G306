# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


# Load an color image in grayscale
imgRGB = cv2.imread('eyeOpenCrop.jpg',1)

imgGrey = cv2.imread('eyeOpenCrop.jpg',0  )

#img = cv2.medianBlur(img,5)






cimg=cv2.cvtColor(imgRGB,cv2.COLOR_RGB2BGR)
plt.imshow(cimg)
plt.
plt.show()

cimg=cv2.cvtColor(imgGrey,cv2.COLOR_GRAY2BGR )
plt.imshow(cimg)
plt.show()

# %%
    
cimg=cv2.cvtColor(imgGrey,cv2.COLOR_BGR2RGB)
plt.imshow(cimg)
plt.show()

#cv2.imshow('detected circles',cimg)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
print("hello")
# Out:
# hello
