# %% [markdown]
# # FIND IRIS

# %%
from matplotlib import pyplot as plt
plt.show()

# %%
import glob
from PIL import Image
import cv2 
import numpy as np
import types
import os
import m3Iris, m3F
inputFolder = "eyes/"
outputFolder = "irises/"
irisesExpected = m3F.filecount(inputFolder)
irisesFound = 0

inputImages=glob.glob(inputFolder + "*.j*")

for imagePath in inputImages:
    
    # if outfolder does not exist, create it
    if not (os.path.exists(outputFolder)):
            os.mkdir(outputFolder)
            print("output folder did not exist,", outputFolder, "created.")
    

    # DO STUFF TO ALL IMAGES BELOW (SENDS IMAGEPATH TO YOUR FUNCTIONS)
    # *************************
    if (m3F.evalSize(imagePath,10,10)):
        
        imgOut = m3Iris.findCircle(imagePath)
    else:
        print("****************************************************************************************************************")
        m3F.printRed("####IMAGE TOOO SMALL###")
        continue;
        # *************************

     #change imagePath from input folder to output folder
    imagePath = imagePath.replace(inputFolder, "")
    imagePath = outputFolder + imagePath
    print("imagePath", imagePath)
    print("length",len(imgOut))
    
    if (type(imgOut) == type(list())):
        #print("was list")
        # if output 
        eyes = iter(imgOut) # used to iterate thru an array. the output of first next() is the first element of array, and so on
        
        cv2.imwrite(imagePath,next(eyes))
        irisesFound += 1
    else:
        if not(type(imgOut) == type(None)):
            cv2.imwrite(imagePath,imgOut)
            irisesFound += 1
        #else:   
            #m3F.printRed("IMAGE NULL")
            
m3F.printBlue("Found {}% of irises in the images".format(irisesFound/irisesExpected*100))
# Out:
# ****************************************************************************************************************
# proccesing eyes\photo10_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo10_Face_1_Left.jpeg
# length 68
# ****************************************************************************************************************
# proccesing eyes\photo10_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo10_Face_1_Right.jpeg
# length 64
# ****************************************************************************************************************
# proccesing eyes\photo11_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo11_Face_1_Left.jpeg
# length 69
# ****************************************************************************************************************
# proccesing eyes\photo11_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo11_Face_1_Right.jpeg
# length 65
# ****************************************************************************************************************
# proccesing eyes\photo12_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo12_Face_1_Left.jpeg
# length 95
# ****************************************************************************************************************
# proccesing eyes\photo12_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo12_Face_1_Right.jpeg
# length 94
# ****************************************************************************************************************
# proccesing eyes\photo13_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo13_Face_1_Left.jpeg
# length 66
# ****************************************************************************************************************
# proccesing eyes\photo13_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo13_Face_1_Right.jpeg
# length 67
# ****************************************************************************************************************
# proccesing eyes\photo14_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo14_Face_1_Left.jpeg
# length 74
# ****************************************************************************************************************
# proccesing eyes\photo14_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo14_Face_1_Right.jpeg
# length 73
# ****************************************************************************************************************
# proccesing eyes\photo15_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo15_Face_1_Left.jpeg
# length 46
# ****************************************************************************************************************
# proccesing eyes\photo15_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo15_Face_1_Right.jpeg
# length 45
# ****************************************************************************************************************
# proccesing eyes\photo16_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo16_Face_1_Left.jpeg
# length 26
# ****************************************************************************************************************
# proccesing eyes\photo16_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo16_Face_1_Right.jpeg
# length 30
# ****************************************************************************************************************
# proccesing eyes\photo17_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo17_Face_1_Left.jpeg
# length 64
# ****************************************************************************************************************
# proccesing eyes\photo17_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo17_Face_1_Right.jpeg
# length 63
# ****************************************************************************************************************
# proccesing eyes\photo18_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo18_Face_1_Left.jpeg
# length 94
# ****************************************************************************************************************
# proccesing eyes\photo18_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo18_Face_1_Right.jpeg
# length 94
# ****************************************************************************************************************
# proccesing eyes\photo19_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo19_Face_1_Left.jpeg
# length 104
# ****************************************************************************************************************
# proccesing eyes\photo19_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo19_Face_1_Right.jpeg
# length 99
# ****************************************************************************************************************
# proccesing eyes\photo2_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo2_Face_1_Left.jpeg
# length 25
# ****************************************************************************************************************
# proccesing eyes\photo2_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo2_Face_1_Right.jpeg
# length 25
# ****************************************************************************************************************
# proccesing eyes\photo3_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo3_Face_1_Left.jpeg
# length 25
# ****************************************************************************************************************
# proccesing eyes\photo3_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo3_Face_1_Right.jpeg
# length 25
# ****************************************************************************************************************
# proccesing eyes\photo4_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo4_Face_1_Left.jpeg
# length 44
# ****************************************************************************************************************
# proccesing eyes\photo4_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo4_Face_1_Right.jpeg
# length 48
# ****************************************************************************************************************
# proccesing eyes\photo6_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo6_Face_1_Left.jpeg
# length 32
# ****************************************************************************************************************
# proccesing eyes\photo6_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo6_Face_1_Right.jpeg
# length 31
# ****************************************************************************************************************
# proccesing eyes\photo8_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo8_Face_1_Left.jpeg
# length 26
# ****************************************************************************************************************
# proccesing eyes\photo8_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo8_Face_1_Right.jpeg
# length 28
# ****************************************************************************************************************
# proccesing eyes\photo9_Face_1_Left.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo9_Face_1_Left.jpeg
# length 67
# ****************************************************************************************************************
# proccesing eyes\photo9_Face_1_Right.jpeg
# CIRCLES FOUND^^^\]
# imagePath irises/eyes\photo9_Face_1_Right.jpeg
# length 64
# Found 100.0% of irises in the images\]
