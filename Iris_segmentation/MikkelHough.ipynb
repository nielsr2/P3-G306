# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


# Load an color image in grayscale
imgRGB = cv2.imread('eyeOpenCrop.jpg',1)

imgGrey = cv2.imread('eyeOpenCrop.jpg',0  )

#img = cv2.medianBlur(img,5)






imgRGB=cv2.cvtColor(imgRGB,cv2.COLOR_RGB2BGR)
plt.imshow(imgRGB)
plt.show()

cimg=cv2.cvtColor(imgGrey,cv2.COLOR_GRAY2BGR )
plt.imshow(cimg)
plt.show()

# %%
imgGrey = cv2.medianBlur(imgGrey,17)

cimg=cv2.cvtColor(imgGrey,cv2.COLOR_GRAY2BGR )
plt.imshow(cimg)
plt.show()

# %%
cimg = cv2.cvtColor(imgGrey,cv2.COLOR_GRAY2BGR)
circles = cv2.HoughCircles(imgGrey,cv2.HOUGH_GRADIENT,1,20,param1=50,param2=30,minRadius=0,maxRadius=0)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

plt.imshow(cimg)
plt.show()
